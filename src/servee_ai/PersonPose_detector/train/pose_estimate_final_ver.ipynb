# %%
import pandas as pd
import numpy as np
import re

fixed_time_steps = 15

# CSV 파일 불러오기
data_df = pd.read_csv('/home/heechun/final_ws/PoseEstimate/1114_final_pose_check/data_frame/data_sequences.csv')
labels_df = pd.read_csv('/home/heechun/final_ws/PoseEstimate/1114_final_pose_check/data_frame/label_sequences.csv')

# 숫자 부분만 추출하는 함수 정의
def extract_numeric(value):
    # tensor(숫자) 형식에서 숫자만 추출
    match = re.search(r"tensor\(([\d.]+)", str(value))
    return float(match.group(1)) if match else np.nan

# 데이터 프레임 전체에 함수 적용
data_df = data_df.applymap(extract_numeric)

# 필요한 형식으로 변환
data_sequences = data_df.values.reshape(-1, fixed_time_steps, 34)  # 시퀀스의 개수 x 시퀀스 길이 x 특징 수
label_sequences = labels_df['label'].values  # 라벨 데이터

# 확인
print("Data shape:", data_sequences.shape)
print("Labels shape:", label_sequences.shape)
# Out:
# /tmp/ipykernel_862825/4163251963.py:18: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data_df = data_df.applymap(extract_numeric)
# Data shape: (1010, 15, 34)
# Labels shape: (1010,)

# %%
data_sequences.shape, label_sequences.shape
# Out:
# ((1010, 15, 34), (1010,))

# %%
data_df.shape, labels_df.shape
# Out:
# ((15150, 34), (1010, 1))

# %%
data_df.head()
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15150 entries, 0 to 15149
# Data columns (total 34 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       15148 non-null  float64
#  1   1       15148 non-null  float64
#  2   2       15148 non-null  float64
#  3   3       15148 non-null  float64
#  4   4       15148 non-null  float64
#  5   5       15148 non-null  float64
#  6   6       15148 non-null  float64
#  7   7       15148 non-null  float64
#  8   8       15148 non-null  float64
#  9   9       15148 non-null  float64
#  10  10      15148 non-null  float64
#  11  11      15148 non-null  float64
#  12  12      15148 non-null  float64
#  13  13      15148 non-null  float64
#  14  14      15148 non-null  float64
#  15  15      15148 non-null  float64
#  16  16      15148 non-null  float64
#  17  17      15148 non-null  float64
#  18  18      15148 non-null  float64
#  19  19      15148 non-null  float64
#  20  20      15148 non-null  float64
#  21  21      15148 non-null  float64
#  22  22      15148 non-null  float64
#  23  23      15148 non-null  float64
#  24  24      15148 non-null  float64
#  25  25      15148 non-null  float64
#  26  26      15148 non-null  float64
#  27  27      15148 non-null  float64
#  28  28      15148 non-null  float64
#  29  29      15148 non-null  float64
#  30  30      15148 non-null  float64
#  31  31      15148 non-null  float64
#  32  32      15148 non-null  float64
#  33  33      15148 non-null  float64
# dtypes: float64(34)
# memory usage: 3.9 MB

# %%
# NaN 값이 있는지 확인
print(np.isnan(data_sequences).any())
# Out:
# True

# %%
data_sequences = np.nan_to_num(data_sequences)

# %%
print(np.isnan(data_sequences).any())
# Out:
# False

# %%
data_sequences.shape
# Out:
# (1010, 15, 34)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import os

# 레이블 인코딩
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(label_sequences)

# 데이터 분할 (학습/검증 데이터)
X_train, X_val, y_train, y_val = train_test_split(data_sequences, encoded_labels, test_size=0.2, random_state=42)

# 양방향 LSTM 모델 정의 (LSTM 유닛 수 증가, 추가 LSTM 층 추가)
model = Sequential([
    Bidirectional(LSTM(256, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.5),
    BatchNormalization(),
    Bidirectional(LSTM(128, return_sequences=True)),  # 추가된 LSTM 층
    Dropout(0.5),
    BatchNormalization(),
    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.5),
    BatchNormalization(),
    Bidirectional(LSTM(32, return_sequences=False)),
    Dropout(0.5),
    Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.03)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.03)),
    BatchNormalization(),
    Dense(len(set(encoded_labels)), activation='softmax')
])

# 모델 컴파일 (초기 학습률 증가)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 로그 디렉토리 설정
log_dir = "/home/heechun/final_ws/PoseEstimate/1114_final_pose_check/logs_final_03"
os.makedirs(log_dir, exist_ok=True)

# TensorBoard 콜백 설정
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# ModelCheckpoint 콜백 설정
checkpoint_best = ModelCheckpoint(
    '/home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# Early Stopping 설정
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

# 학습률 감소 스케줄러 설정
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    verbose=1
)

# 모델 학습
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint_best, tensorboard_callback, early_stopping, lr_scheduler]
)

# 최종 모델 저장 - best 모델만 저장함
# model.save('/home/heechun/final_ws/PoseEstimate/1114_final_pose_check/final_model_01.keras')
# Out:
# /home/heechun/venv/md_ven/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2733 - loss: 5.0011
# Epoch 1: val_accuracy improved from -inf to 0.26238, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.2718 - loss: 5.0028 - val_accuracy: 0.2624 - val_loss: 4.5043 - learning_rate: 1.0000e-04
# Epoch 2/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2793 - loss: 4.9249
# Epoch 2: val_accuracy did not improve from 0.26238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.2804 - loss: 4.9231 - val_accuracy: 0.2624 - val_loss: 4.5055 - learning_rate: 1.0000e-04
# Epoch 3/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2739 - loss: 4.9117
# Epoch 3: val_accuracy did not improve from 0.26238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.2752 - loss: 4.9075 - val_accuracy: 0.2624 - val_loss: 4.5129 - learning_rate: 1.0000e-04
# Epoch 4/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3155 - loss: 4.7532
# Epoch 4: val_accuracy did not improve from 0.26238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.3136 - loss: 4.7540 - val_accuracy: 0.2624 - val_loss: 4.5104 - learning_rate: 1.0000e-04
# Epoch 5/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3137 - loss: 4.6898
# Epoch 5: val_accuracy did not improve from 0.26238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3142 - loss: 4.6890 - val_accuracy: 0.2624 - val_loss: 4.5064 - learning_rate: 1.0000e-04
# Epoch 6/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3197 - loss: 4.6951
# Epoch 6: val_accuracy did not improve from 0.26238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3190 - loss: 4.6945 - val_accuracy: 0.2624 - val_loss: 4.4605 - learning_rate: 1.0000e-04
# Epoch 7/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3003 - loss: 4.6183
# Epoch 7: val_accuracy did not improve from 0.26238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.2997 - loss: 4.6214 - val_accuracy: 0.2624 - val_loss: 4.4103 - learning_rate: 1.0000e-04
# Epoch 8/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3544 - loss: 4.5466
# Epoch 8: val_accuracy improved from 0.26238 to 0.29703, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.3542 - loss: 4.5454 - val_accuracy: 0.2970 - val_loss: 4.3505 - learning_rate: 1.0000e-04
# Epoch 9/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3113 - loss: 4.6268
# Epoch 9: val_accuracy improved from 0.29703 to 0.30693, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.3119 - loss: 4.6204 - val_accuracy: 0.3069 - val_loss: 4.2934 - learning_rate: 1.0000e-04
# Epoch 10/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3827 - loss: 4.3812
# Epoch 10: val_accuracy improved from 0.30693 to 0.36634, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.3805 - loss: 4.3853 - val_accuracy: 0.3663 - val_loss: 4.2071 - learning_rate: 1.0000e-04
# Epoch 11/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3233 - loss: 4.3971
# Epoch 11: val_accuracy improved from 0.36634 to 0.45545, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.3244 - loss: 4.3962 - val_accuracy: 0.4554 - val_loss: 4.0685 - learning_rate: 1.0000e-04
# Epoch 12/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3491 - loss: 4.3504
# Epoch 12: val_accuracy improved from 0.45545 to 0.58911, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.3503 - loss: 4.3489 - val_accuracy: 0.5891 - val_loss: 3.9417 - learning_rate: 1.0000e-04
# Epoch 13/100
# 23/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3830 - loss: 4.2741
# Epoch 13: val_accuracy improved from 0.58911 to 0.59901, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.3812 - loss: 4.2744 - val_accuracy: 0.5990 - val_loss: 3.8998 - learning_rate: 1.0000e-04
# Epoch 14/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3559 - loss: 4.3279
# Epoch 14: val_accuracy improved from 0.59901 to 0.65347, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.3566 - loss: 4.3260 - val_accuracy: 0.6535 - val_loss: 3.8328 - learning_rate: 1.0000e-04
# Epoch 15/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3393 - loss: 4.2767
# Epoch 15: val_accuracy did not improve from 0.65347
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.3434 - loss: 4.2686 - val_accuracy: 0.6337 - val_loss: 3.7920 - learning_rate: 1.0000e-04
# Epoch 16/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3803 - loss: 4.2025
# Epoch 16: val_accuracy improved from 0.65347 to 0.68317, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.3820 - loss: 4.1979 - val_accuracy: 0.6832 - val_loss: 3.7081 - learning_rate: 1.0000e-04
# Epoch 17/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4327 - loss: 4.0719
# Epoch 17: val_accuracy did not improve from 0.68317
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.4297 - loss: 4.0779 - val_accuracy: 0.6782 - val_loss: 3.6468 - learning_rate: 1.0000e-04
# Epoch 18/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4327 - loss: 4.0456
# Epoch 18: val_accuracy improved from 0.68317 to 0.69802, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.4334 - loss: 4.0440 - val_accuracy: 0.6980 - val_loss: 3.6088 - learning_rate: 1.0000e-04
# Epoch 19/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4807 - loss: 3.9254
# Epoch 19: val_accuracy did not improve from 0.69802
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.4794 - loss: 3.9255 - val_accuracy: 0.6980 - val_loss: 3.5551 - learning_rate: 1.0000e-04
# Epoch 20/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4552 - loss: 3.9310
# Epoch 20: val_accuracy did not improve from 0.69802
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.4560 - loss: 3.9285 - val_accuracy: 0.6733 - val_loss: 3.4679 - learning_rate: 1.0000e-04
# Epoch 21/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4380 - loss: 3.9630
# Epoch 21: val_accuracy did not improve from 0.69802
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.4397 - loss: 3.9584 - val_accuracy: 0.6535 - val_loss: 3.4311 - learning_rate: 1.0000e-04
# Epoch 22/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4556 - loss: 3.8862
# Epoch 22: val_accuracy improved from 0.69802 to 0.76238, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.4562 - loss: 3.8838 - val_accuracy: 0.7624 - val_loss: 3.3662 - learning_rate: 1.0000e-04
# Epoch 23/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4547 - loss: 3.8296
# Epoch 23: val_accuracy did not improve from 0.76238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.4555 - loss: 3.8275 - val_accuracy: 0.6980 - val_loss: 3.3723 - learning_rate: 1.0000e-04
# Epoch 24/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4649 - loss: 3.7816
# Epoch 24: val_accuracy did not improve from 0.76238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.4654 - loss: 3.7811 - val_accuracy: 0.6980 - val_loss: 3.3195 - learning_rate: 1.0000e-04
# Epoch 25/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4893 - loss: 3.7310
# Epoch 25: val_accuracy did not improve from 0.76238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.4894 - loss: 3.7308 - val_accuracy: 0.7624 - val_loss: 3.2305 - learning_rate: 1.0000e-04
# Epoch 26/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5129 - loss: 3.6758
# Epoch 26: val_accuracy did not improve from 0.76238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5131 - loss: 3.6747 - val_accuracy: 0.7525 - val_loss: 3.1860 - learning_rate: 1.0000e-04
# Epoch 27/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5289 - loss: 3.6122
# Epoch 27: val_accuracy did not improve from 0.76238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5296 - loss: 3.6102 - val_accuracy: 0.7525 - val_loss: 3.1705 - learning_rate: 1.0000e-04
# Epoch 28/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5458 - loss: 3.5651
# Epoch 28: val_accuracy did not improve from 0.76238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5459 - loss: 3.5636 - val_accuracy: 0.7475 - val_loss: 3.1703 - learning_rate: 1.0000e-04
# Epoch 29/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5604 - loss: 3.5308
# Epoch 29: val_accuracy did not improve from 0.76238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5573 - loss: 3.5335 - val_accuracy: 0.7475 - val_loss: 3.1005 - learning_rate: 1.0000e-04
# Epoch 30/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5810 - loss: 3.4712
# Epoch 30: val_accuracy did not improve from 0.76238
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5817 - loss: 3.4686 - val_accuracy: 0.7525 - val_loss: 3.0977 - learning_rate: 1.0000e-04
# Epoch 31/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5996 - loss: 3.4098
# Epoch 31: val_accuracy improved from 0.76238 to 0.76733, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.6004 - loss: 3.4085 - val_accuracy: 0.7673 - val_loss: 3.0077 - learning_rate: 1.0000e-04
# Epoch 32/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5686 - loss: 3.4102
# Epoch 32: val_accuracy improved from 0.76733 to 0.77228, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5685 - loss: 3.4087 - val_accuracy: 0.7723 - val_loss: 2.9730 - learning_rate: 1.0000e-04
# Epoch 33/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6019 - loss: 3.3531
# Epoch 33: val_accuracy improved from 0.77228 to 0.77723, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6018 - loss: 3.3512 - val_accuracy: 0.7772 - val_loss: 2.9323 - learning_rate: 1.0000e-04
# Epoch 34/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6137 - loss: 3.3297
# Epoch 34: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6138 - loss: 3.3281 - val_accuracy: 0.7475 - val_loss: 2.9313 - learning_rate: 1.0000e-04
# Epoch 35/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6000 - loss: 3.2877
# Epoch 35: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6002 - loss: 3.2861 - val_accuracy: 0.7624 - val_loss: 2.9037 - learning_rate: 1.0000e-04
# Epoch 36/100
# 23/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6374 - loss: 3.1821
# Epoch 36: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6371 - loss: 3.1863 - val_accuracy: 0.7723 - val_loss: 2.8508 - learning_rate: 1.0000e-04
# Epoch 37/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6272 - loss: 3.1663
# Epoch 37: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6270 - loss: 3.1681 - val_accuracy: 0.7772 - val_loss: 2.8232 - learning_rate: 1.0000e-04
# Epoch 38/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6272 - loss: 3.1611
# Epoch 38: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6288 - loss: 3.1575 - val_accuracy: 0.7723 - val_loss: 2.8090 - learning_rate: 1.0000e-04
# Epoch 39/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6251 - loss: 3.1709
# Epoch 39: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6248 - loss: 3.1688 - val_accuracy: 0.7673 - val_loss: 2.7879 - learning_rate: 1.0000e-04
# Epoch 40/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6480 - loss: 3.0508
# Epoch 40: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6478 - loss: 3.0518 - val_accuracy: 0.7723 - val_loss: 2.7355 - learning_rate: 1.0000e-04
# Epoch 41/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7057 - loss: 2.9985
# Epoch 41: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7041 - loss: 2.9993 - val_accuracy: 0.7673 - val_loss: 2.7467 - learning_rate: 1.0000e-04
# Epoch 42/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6818 - loss: 3.0082
# Epoch 42: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6830 - loss: 3.0050 - val_accuracy: 0.7673 - val_loss: 2.7179 - learning_rate: 1.0000e-04
# Epoch 43/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6873 - loss: 2.9405
# Epoch 43: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6866 - loss: 2.9404 - val_accuracy: 0.7772 - val_loss: 2.6710 - learning_rate: 1.0000e-04
# Epoch 44/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6443 - loss: 2.9465
# Epoch 44: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6457 - loss: 2.9448 - val_accuracy: 0.7772 - val_loss: 2.6455 - learning_rate: 1.0000e-04
# Epoch 45/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6907 - loss: 2.8408
# Epoch 45: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6898 - loss: 2.8424 - val_accuracy: 0.7475 - val_loss: 2.6846 - learning_rate: 1.0000e-04
# Epoch 46/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6952 - loss: 2.8321
# Epoch 46: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6948 - loss: 2.8355 - val_accuracy: 0.7624 - val_loss: 2.6469 - learning_rate: 1.0000e-04
# Epoch 47/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6854 - loss: 2.8536
# Epoch 47: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6863 - loss: 2.8518 - val_accuracy: 0.7723 - val_loss: 2.5641 - learning_rate: 1.0000e-04
# Epoch 48/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6768 - loss: 2.8243
# Epoch 48: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6776 - loss: 2.8226 - val_accuracy: 0.7772 - val_loss: 2.5437 - learning_rate: 1.0000e-04
# Epoch 49/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6632 - loss: 2.7804
# Epoch 49: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6657 - loss: 2.7785 - val_accuracy: 0.7723 - val_loss: 2.5181 - learning_rate: 1.0000e-04
# Epoch 50/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7064 - loss: 2.7122
# Epoch 50: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7064 - loss: 2.7124 - val_accuracy: 0.7723 - val_loss: 2.4887 - learning_rate: 1.0000e-04
# Epoch 51/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6986 - loss: 2.6893
# Epoch 51: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7001 - loss: 2.6879 - val_accuracy: 0.7772 - val_loss: 2.4544 - learning_rate: 1.0000e-04
# Epoch 52/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7016 - loss: 2.7004
# Epoch 52: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7031 - loss: 2.6962 - val_accuracy: 0.7723 - val_loss: 2.4496 - learning_rate: 1.0000e-04
# Epoch 53/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7048 - loss: 2.6053
# Epoch 53: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7037 - loss: 2.6072 - val_accuracy: 0.7772 - val_loss: 2.4090 - learning_rate: 1.0000e-04
# Epoch 54/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6820 - loss: 2.6654
# Epoch 54: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6821 - loss: 2.6639 - val_accuracy: 0.7772 - val_loss: 2.4133 - learning_rate: 1.0000e-04
# Epoch 55/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6936 - loss: 2.5892
# Epoch 55: val_accuracy did not improve from 0.77723
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6944 - loss: 2.5886 - val_accuracy: 0.7772 - val_loss: 2.3734 - learning_rate: 1.0000e-04
# Epoch 56/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7065 - loss: 2.5643
# Epoch 56: val_accuracy improved from 0.77723 to 0.78218, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7066 - loss: 2.5651 - val_accuracy: 0.7822 - val_loss: 2.3336 - learning_rate: 1.0000e-04
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6909 - loss: 2.5691
# Epoch 57: val_accuracy did not improve from 0.78218
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.6915 - loss: 2.5692 - val_accuracy: 0.7723 - val_loss: 2.3733 - learning_rate: 1.0000e-04
# Epoch 58/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7395 - loss: 2.4896
# Epoch 58: val_accuracy did not improve from 0.78218
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7384 - loss: 2.4890 - val_accuracy: 0.7822 - val_loss: 2.2909 - learning_rate: 1.0000e-04
# Epoch 59/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6979 - loss: 2.5172
# Epoch 59: val_accuracy did not improve from 0.78218
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6973 - loss: 2.5153 - val_accuracy: 0.5842 - val_loss: 3.6405 - learning_rate: 1.0000e-04
# Epoch 60/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7341 - loss: 2.4279
# Epoch 60: val_accuracy did not improve from 0.78218
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7332 - loss: 2.4295 - val_accuracy: 0.7772 - val_loss: 2.2587 - learning_rate: 1.0000e-04
# Epoch 61/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7338 - loss: 2.3923
# Epoch 61: val_accuracy did not improve from 0.78218
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7330 - loss: 2.3937 - val_accuracy: 0.7822 - val_loss: 2.2257 - learning_rate: 1.0000e-04
# Epoch 62/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6816 - loss: 2.4346
# Epoch 62: val_accuracy did not improve from 0.78218
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6811 - loss: 2.4364 - val_accuracy: 0.7772 - val_loss: 2.1902 - learning_rate: 1.0000e-04
# Epoch 63/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7294 - loss: 2.3528
# Epoch 63: val_accuracy did not improve from 0.78218
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7290 - loss: 2.3540 - val_accuracy: 0.7723 - val_loss: 2.2815 - learning_rate: 1.0000e-04
# Epoch 64/100
# 23/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7164 - loss: 2.3618
# Epoch 64: val_accuracy improved from 0.78218 to 0.79208, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7155 - loss: 2.3611 - val_accuracy: 0.7921 - val_loss: 2.1746 - learning_rate: 1.0000e-04
# Epoch 65/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6882 - loss: 2.3492
# Epoch 65: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6901 - loss: 2.3492 - val_accuracy: 0.7772 - val_loss: 2.1356 - learning_rate: 1.0000e-04
# Epoch 66/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7010 - loss: 2.2870
# Epoch 66: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7007 - loss: 2.2882 - val_accuracy: 0.7772 - val_loss: 2.1077 - learning_rate: 1.0000e-04
# Epoch 67/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7129 - loss: 2.2850
# Epoch 67: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7130 - loss: 2.2840 - val_accuracy: 0.7822 - val_loss: 2.1073 - learning_rate: 1.0000e-04
# Epoch 68/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7640 - loss: 2.2380
# Epoch 68: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7631 - loss: 2.2379 - val_accuracy: 0.7327 - val_loss: 2.3743 - learning_rate: 1.0000e-04
# Epoch 69/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6963 - loss: 2.2313
# Epoch 69: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6972 - loss: 2.2310 - val_accuracy: 0.7079 - val_loss: 2.2460 - learning_rate: 1.0000e-04
# Epoch 70/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7117 - loss: 2.2118
# Epoch 70: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7118 - loss: 2.2141 - val_accuracy: 0.7772 - val_loss: 2.0281 - learning_rate: 1.0000e-04
# Epoch 71/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7352 - loss: 2.1870
# Epoch 71: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7351 - loss: 2.1870 - val_accuracy: 0.7772 - val_loss: 2.0015 - learning_rate: 1.0000e-04
# Epoch 72/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7160 - loss: 2.1545
# Epoch 72: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7176 - loss: 2.1529 - val_accuracy: 0.7624 - val_loss: 2.0151 - learning_rate: 1.0000e-04
# Epoch 73/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7248 - loss: 2.1306
# Epoch 73: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7249 - loss: 2.1303 - val_accuracy: 0.7772 - val_loss: 1.9586 - learning_rate: 1.0000e-04
# Epoch 74/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7332 - loss: 2.1153
# Epoch 74: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7339 - loss: 2.1148 - val_accuracy: 0.6337 - val_loss: 2.5241 - learning_rate: 1.0000e-04
# Epoch 75/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7292 - loss: 2.1059
# Epoch 75: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7287 - loss: 2.1063 - val_accuracy: 0.7772 - val_loss: 1.9210 - learning_rate: 1.0000e-04
# Epoch 76/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7283 - loss: 2.0678
# Epoch 76: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7269 - loss: 2.0686 - val_accuracy: 0.7822 - val_loss: 1.8925 - learning_rate: 1.0000e-04
# Epoch 77/100
# 23/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7122 - loss: 2.0520
# Epoch 77: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.7153 - loss: 2.0514 - val_accuracy: 0.7822 - val_loss: 1.9340 - learning_rate: 1.0000e-04
# Epoch 78/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7472 - loss: 2.0165
# Epoch 78: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7460 - loss: 2.0182 - val_accuracy: 0.7772 - val_loss: 1.8665 - learning_rate: 1.0000e-04
# Epoch 79/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7266 - loss: 2.0280
# Epoch 79: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7276 - loss: 2.0255 - val_accuracy: 0.7772 - val_loss: 1.8397 - learning_rate: 1.0000e-04
# Epoch 80/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7271 - loss: 1.9914
# Epoch 80: val_accuracy did not improve from 0.79208
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7270 - loss: 1.9921 - val_accuracy: 0.7871 - val_loss: 1.8153 - learning_rate: 1.0000e-04
# Epoch 81/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7275 - loss: 1.9666
# Epoch 81: val_accuracy improved from 0.79208 to 0.80198, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7269 - loss: 1.9657 - val_accuracy: 0.8020 - val_loss: 1.8039 - learning_rate: 1.0000e-04
# Epoch 82/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7278 - loss: 1.9978
# Epoch 82: val_accuracy improved from 0.80198 to 0.81188, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_03.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7275 - loss: 1.9968 - val_accuracy: 0.8119 - val_loss: 1.7856 - learning_rate: 1.0000e-04
# Epoch 83/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7164 - loss: 1.9593
# Epoch 83: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7190 - loss: 1.9551 - val_accuracy: 0.8119 - val_loss: 1.7660 - learning_rate: 1.0000e-04
# Epoch 84/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7592 - loss: 1.9182
# Epoch 84: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7604 - loss: 1.9142 - val_accuracy: 0.7723 - val_loss: 1.7531 - learning_rate: 1.0000e-04
# Epoch 85/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7529 - loss: 1.8873
# Epoch 85: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7523 - loss: 1.8868 - val_accuracy: 0.7822 - val_loss: 1.7314 - learning_rate: 1.0000e-04
# Epoch 86/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7366 - loss: 1.8556
# Epoch 86: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7375 - loss: 1.8554 - val_accuracy: 0.7772 - val_loss: 1.7133 - learning_rate: 1.0000e-04
# Epoch 87/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7342 - loss: 1.8858
# Epoch 87: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7352 - loss: 1.8844 - val_accuracy: 0.7772 - val_loss: 1.7042 - learning_rate: 1.0000e-04
# Epoch 88/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7392 - loss: 1.8332
# Epoch 88: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7393 - loss: 1.8320 - val_accuracy: 0.7574 - val_loss: 1.7081 - learning_rate: 1.0000e-04
# Epoch 89/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7511 - loss: 1.7813
# Epoch 89: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7511 - loss: 1.7817 - val_accuracy: 0.7772 - val_loss: 1.6539 - learning_rate: 1.0000e-04
# Epoch 90/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7294 - loss: 1.7966
# Epoch 90: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7296 - loss: 1.7957 - val_accuracy: 0.7772 - val_loss: 1.6552 - learning_rate: 1.0000e-04
# Epoch 91/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7479 - loss: 1.7707
# Epoch 91: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7499 - loss: 1.7694 - val_accuracy: 0.7673 - val_loss: 1.7968 - learning_rate: 1.0000e-04
# Epoch 92/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7560 - loss: 1.7167
# Epoch 92: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7559 - loss: 1.7169 - val_accuracy: 0.7426 - val_loss: 1.7357 - learning_rate: 1.0000e-04
# Epoch 93/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7539 - loss: 1.7519
# Epoch 93: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7523 - loss: 1.7528 - val_accuracy: 0.7822 - val_loss: 1.5874 - learning_rate: 1.0000e-04
# Epoch 94/100
# 23/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7178 - loss: 1.7288
# Epoch 94: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.7192 - loss: 1.7286 - val_accuracy: 0.7871 - val_loss: 1.5623 - learning_rate: 1.0000e-04
# Epoch 95/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7796 - loss: 1.6634
# Epoch 95: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7764 - loss: 1.6647 - val_accuracy: 0.7673 - val_loss: 1.5829 - learning_rate: 1.0000e-04
# Epoch 96/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7399 - loss: 1.6477
# Epoch 96: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7400 - loss: 1.6497 - val_accuracy: 0.7772 - val_loss: 1.5377 - learning_rate: 1.0000e-04
# Epoch 97/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7469 - loss: 1.6492
# Epoch 97: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7480 - loss: 1.6504 - val_accuracy: 0.7822 - val_loss: 1.5256 - learning_rate: 1.0000e-04
# Epoch 98/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7507 - loss: 1.6084
# Epoch 98: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7506 - loss: 1.6126 - val_accuracy: 0.7525 - val_loss: 1.7606 - learning_rate: 1.0000e-04
# Epoch 99/100
# 23/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7648 - loss: 1.5993
# Epoch 99: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7655 - loss: 1.5981 - val_accuracy: 0.7772 - val_loss: 1.4936 - learning_rate: 1.0000e-04
# Epoch 100/100
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7381 - loss: 1.6180
# Epoch 100: val_accuracy did not improve from 0.81188
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7385 - loss: 1.6174 - val_accuracy: 0.7970 - val_loss: 1.5636 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 99.

# %%
# !tensorboard --logdir=/home/heechun/final_ws/PoseEstimate/1114_final_pose_check/logs_final_01
# Out:
# 2024-11-14 17:36:46.821647: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-14 17:36:46.836421: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-14 17:36:46.840936: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-14 17:36:46.852309: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-14 17:36:47.591203: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731573408.387046  865585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731573408.415853  865585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731573408.416174  865585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.17.1 at http://localhost:6007/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# # 1. 데이터 로딩 및 증강 처리

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

fixed_time_steps = 15

# CSV 파일 불러오기
data_df = pd.read_csv('/home/heechun/final_ws/PoseEstimate/1114_final_pose_check/data_frame/data_sequences.csv')
labels_df = pd.read_csv('/home/heechun/final_ws/PoseEstimate/1114_final_pose_check/data_frame/label_sequences.csv')

# 숫자 부분만 추출하는 함수 정의
def extract_numeric(value):
    # tensor(숫자) 형식에서 숫자만 추출
    match = re.search(r"tensor\(([\d.]+)", str(value))
    return float(match.group(1)) if match else np.nan

# 데이터 프레임 전체에 함수 적용
data_df = data_df.applymap(extract_numeric)

# 필요한 형식으로 변환
data_sequences = data_df.values.reshape(-1, fixed_time_steps, 34)  # 시퀀스의 개수 x 시퀀스 길이 x 특징 수
label_sequences = labels_df['label'].values  # 라벨 데이터

# NaN 값 처리
data_sequences = np.nan_to_num(data_sequences)

# 데이터 증강 함수 정의
def add_noise(data, noise_factor=0.1):
    noise = noise_factor * np.random.randn(*data.shape)
    return data + noise

def scale(data, scale_factor=1.1):
    return data * scale_factor

def shift(data, shift_max=0.1):
    shift = np.random.uniform(-shift_max, shift_max, data.shape)
    return data + shift

# 데이터 증강 적용
augmented_data_sequences = []
augmented_labels = []

for i in range(len(data_sequences)):
    original = data_sequences[i]
    
    # 원본 추가
    augmented_data_sequences.append(original)
    augmented_labels.append(label_sequences[i])
    
    # Noise 추가
    augmented_data_sequences.append(add_noise(original))
    augmented_labels.append(label_sequences[i])

    # Scaling 추가
    augmented_data_sequences.append(scale(original))
    augmented_labels.append(label_sequences[i])

    # Shifting 추가
    augmented_data_sequences.append(shift(original))
    augmented_labels.append(label_sequences[i])

# 증강된 데이터 변환
augmented_data_sequences = np.array(augmented_data_sequences)
augmented_labels = np.array(augmented_labels)

# 레이블 인코딩
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(augmented_labels)

# 데이터 분할 (학습/검증 데이터)
X_train, X_val, y_train, y_val = train_test_split(augmented_data_sequences, encoded_labels, test_size=0.2, random_state=42)
# Out:
# /tmp/ipykernel_862825/1207425814.py:20: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data_df = data_df.applymap(extract_numeric)

# %% [markdown]
# # 2. 모델 정의 및 학습 설정

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping, ReduceLROnPlateau
import os

# 양방향 LSTM 모델 정의 (LSTM 유닛 수 증가, 추가 LSTM 층 추가)
model = Sequential([
    Bidirectional(LSTM(256, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.5),
    BatchNormalization(),
    Bidirectional(LSTM(128, return_sequences=True)),  # 추가된 LSTM 층
    Dropout(0.5),
    BatchNormalization(),
    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.5),
    BatchNormalization(),
    Bidirectional(LSTM(32, return_sequences=False)),
    Dropout(0.5),
    Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.03)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.03)),
    BatchNormalization(),
    Dense(len(set(encoded_labels)), activation='softmax')
])

# 모델 컴파일 (초기 학습률 증가)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 로그 디렉토리 설정
log_dir = "/home/heechun/final_ws/PoseEstimate/1114_final_pose_check/logs_final_data_change"
os.makedirs(log_dir, exist_ok=True)

# TensorBoard 콜백 설정
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# ModelCheckpoint 콜백 설정
checkpoint_best = ModelCheckpoint(
    '/home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# Early Stopping 설정
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

# 학습률 감소 스케줄러 설정
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    verbose=1
)

# 모델 학습
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint_best, tensorboard_callback, early_stopping, lr_scheduler]
)
# Out:
# /home/heechun/venv/md_ven/lib/python3.10/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2658 - loss: 4.8641
# Epoch 1: val_accuracy improved from -inf to 0.24010, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.2659 - loss: 4.8634 - val_accuracy: 0.2401 - val_loss: 4.5547 - learning_rate: 1.0000e-04
# Epoch 2/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3002 - loss: 4.6515
# Epoch 2: val_accuracy improved from 0.24010 to 0.37252, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.3002 - loss: 4.6509 - val_accuracy: 0.3725 - val_loss: 4.3976 - learning_rate: 1.0000e-04
# Epoch 3/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3278 - loss: 4.3933
# Epoch 3: val_accuracy improved from 0.37252 to 0.47030, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.3280 - loss: 4.3927 - val_accuracy: 0.4703 - val_loss: 4.0827 - learning_rate: 1.0000e-04
# Epoch 4/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3857 - loss: 4.1814
# Epoch 4: val_accuracy improved from 0.47030 to 0.58416, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.3857 - loss: 4.1810 - val_accuracy: 0.5842 - val_loss: 3.7447 - learning_rate: 1.0000e-04
# Epoch 5/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4197 - loss: 3.9939
# Epoch 5: val_accuracy improved from 0.58416 to 0.63119, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.4198 - loss: 3.9936 - val_accuracy: 0.6312 - val_loss: 3.4732 - learning_rate: 1.0000e-04
# Epoch 6/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4539 - loss: 3.8155
# Epoch 6: val_accuracy improved from 0.63119 to 0.65965, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.4541 - loss: 3.8148 - val_accuracy: 0.6597 - val_loss: 3.3240 - learning_rate: 1.0000e-04
# Epoch 7/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5331 - loss: 3.5617
# Epoch 7: val_accuracy improved from 0.65965 to 0.68193, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5331 - loss: 3.5613 - val_accuracy: 0.6819 - val_loss: 3.1499 - learning_rate: 1.0000e-04
# Epoch 8/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5922 - loss: 3.3553
# Epoch 8: val_accuracy did not improve from 0.68193
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5922 - loss: 3.3551 - val_accuracy: 0.6547 - val_loss: 3.0710 - learning_rate: 1.0000e-04
# Epoch 9/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5830 - loss: 3.2270
# Epoch 9: val_accuracy improved from 0.68193 to 0.71411, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5832 - loss: 3.2265 - val_accuracy: 0.7141 - val_loss: 2.8882 - learning_rate: 1.0000e-04
# Epoch 10/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6307 - loss: 3.0544
# Epoch 10: val_accuracy improved from 0.71411 to 0.72896, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6311 - loss: 3.0532 - val_accuracy: 0.7290 - val_loss: 2.6847 - learning_rate: 1.0000e-04
# Epoch 11/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6435 - loss: 2.8941
# Epoch 11: val_accuracy did not improve from 0.72896
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6441 - loss: 2.8924 - val_accuracy: 0.7104 - val_loss: 2.6001 - learning_rate: 1.0000e-04
# Epoch 12/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6748 - loss: 2.7635
# Epoch 12: val_accuracy did not improve from 0.72896
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.6748 - loss: 2.7623 - val_accuracy: 0.7228 - val_loss: 2.5087 - learning_rate: 1.0000e-04
# Epoch 13/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7116 - loss: 2.5857
# Epoch 13: val_accuracy did not improve from 0.72896
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7115 - loss: 2.5855 - val_accuracy: 0.7228 - val_loss: 2.4276 - learning_rate: 1.0000e-04
# Epoch 14/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6985 - loss: 2.4838
# Epoch 14: val_accuracy did not improve from 0.72896
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.6985 - loss: 2.4836 - val_accuracy: 0.7252 - val_loss: 2.2541 - learning_rate: 1.0000e-04
# Epoch 15/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7169 - loss: 2.3759
# Epoch 15: val_accuracy improved from 0.72896 to 0.73515, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7169 - loss: 2.3755 - val_accuracy: 0.7351 - val_loss: 2.1642 - learning_rate: 1.0000e-04
# Epoch 16/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7275 - loss: 2.2433
# Epoch 16: val_accuracy did not improve from 0.73515
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7274 - loss: 2.2432 - val_accuracy: 0.7351 - val_loss: 2.0647 - learning_rate: 1.0000e-04
# Epoch 17/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7197 - loss: 2.1678
# Epoch 17: val_accuracy did not improve from 0.73515
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7197 - loss: 2.1675 - val_accuracy: 0.7153 - val_loss: 2.0191 - learning_rate: 1.0000e-04
# Epoch 18/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7230 - loss: 2.0691
# Epoch 18: val_accuracy did not improve from 0.73515
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7230 - loss: 2.0689 - val_accuracy: 0.7215 - val_loss: 2.0288 - learning_rate: 1.0000e-04
# Epoch 19/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7070 - loss: 2.0117
# Epoch 19: val_accuracy did not improve from 0.73515
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7072 - loss: 2.0111 - val_accuracy: 0.7302 - val_loss: 1.8837 - learning_rate: 1.0000e-04
# Epoch 20/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7059 - loss: 1.9369
# Epoch 20: val_accuracy did not improve from 0.73515
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7060 - loss: 1.9365 - val_accuracy: 0.7290 - val_loss: 1.7727 - learning_rate: 1.0000e-04
# Epoch 21/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7327 - loss: 1.8253
# Epoch 21: val_accuracy did not improve from 0.73515
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7327 - loss: 1.8250 - val_accuracy: 0.7302 - val_loss: 1.7119 - learning_rate: 1.0000e-04
# Epoch 22/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7378 - loss: 1.7265
# Epoch 22: val_accuracy did not improve from 0.73515
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7378 - loss: 1.7263 - val_accuracy: 0.6708 - val_loss: 1.7817 - learning_rate: 1.0000e-04
# Epoch 23/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7432 - loss: 1.6560
# Epoch 23: val_accuracy improved from 0.73515 to 0.75248, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7432 - loss: 1.6557 - val_accuracy: 0.7525 - val_loss: 1.5981 - learning_rate: 1.0000e-04
# Epoch 24/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7401 - loss: 1.5534
# Epoch 24: val_accuracy did not improve from 0.75248
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7402 - loss: 1.5533 - val_accuracy: 0.7314 - val_loss: 1.4487 - learning_rate: 1.0000e-04
# Epoch 25/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7176 - loss: 1.5238
# Epoch 25: val_accuracy improved from 0.75248 to 0.75743, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7180 - loss: 1.5227 - val_accuracy: 0.7574 - val_loss: 1.4132 - learning_rate: 1.0000e-04
# Epoch 26/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7458 - loss: 1.4392
# Epoch 26: val_accuracy did not improve from 0.75743
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7457 - loss: 1.4387 - val_accuracy: 0.7475 - val_loss: 1.3210 - learning_rate: 1.0000e-04
# Epoch 27/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7430 - loss: 1.3746
# Epoch 27: val_accuracy improved from 0.75743 to 0.79579, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7430 - loss: 1.3744 - val_accuracy: 0.7958 - val_loss: 1.2770 - learning_rate: 1.0000e-04
# Epoch 28/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7577 - loss: 1.3061
# Epoch 28: val_accuracy did not improve from 0.79579
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7577 - loss: 1.3056 - val_accuracy: 0.7748 - val_loss: 1.2091 - learning_rate: 1.0000e-04
# Epoch 29/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7561 - loss: 1.2564
# Epoch 29: val_accuracy did not improve from 0.79579
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7560 - loss: 1.2560 - val_accuracy: 0.6993 - val_loss: 1.5119 - learning_rate: 1.0000e-04
# Epoch 30/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7593 - loss: 1.1980
# Epoch 30: val_accuracy did not improve from 0.79579
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7593 - loss: 1.1978 - val_accuracy: 0.6807 - val_loss: 1.5101 - learning_rate: 1.0000e-04
# Epoch 31/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7584 - loss: 1.1579
# Epoch 31: val_accuracy improved from 0.79579 to 0.81188, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7587 - loss: 1.1570 - val_accuracy: 0.8119 - val_loss: 1.0553 - learning_rate: 1.0000e-04
# Epoch 32/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7622 - loss: 1.0783
# Epoch 32: val_accuracy did not improve from 0.81188
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7624 - loss: 1.0781 - val_accuracy: 0.7822 - val_loss: 1.0210 - learning_rate: 1.0000e-04
# Epoch 33/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7500 - loss: 1.0710
# Epoch 33: val_accuracy improved from 0.81188 to 0.86139, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7508 - loss: 1.0697 - val_accuracy: 0.8614 - val_loss: 0.9319 - learning_rate: 1.0000e-04
# Epoch 34/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7796 - loss: 1.0231
# Epoch 34: val_accuracy did not improve from 0.86139
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7797 - loss: 1.0228 - val_accuracy: 0.6832 - val_loss: 2.0795 - learning_rate: 1.0000e-04
# Epoch 35/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7981 - loss: 0.9502
# Epoch 35: val_accuracy improved from 0.86139 to 0.88985, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7981 - loss: 0.9498 - val_accuracy: 0.8899 - val_loss: 0.8150 - learning_rate: 1.0000e-04
# Epoch 36/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8055 - loss: 0.9054
# Epoch 36: val_accuracy did not improve from 0.88985
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8057 - loss: 0.9048 - val_accuracy: 0.7958 - val_loss: 1.1788 - learning_rate: 1.0000e-04
# Epoch 37/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8275 - loss: 0.8485
# Epoch 37: val_accuracy did not improve from 0.88985
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8276 - loss: 0.8481 - val_accuracy: 0.8861 - val_loss: 0.7579 - learning_rate: 1.0000e-04
# Epoch 38/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8362 - loss: 0.8042
# Epoch 38: val_accuracy did not improve from 0.88985
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8362 - loss: 0.8042 - val_accuracy: 0.8366 - val_loss: 0.8199 - learning_rate: 1.0000e-04
# Epoch 39/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8414 - loss: 0.7734
# Epoch 39: val_accuracy did not improve from 0.88985
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8416 - loss: 0.7728 - val_accuracy: 0.8144 - val_loss: 0.7701 - learning_rate: 1.0000e-04
# Epoch 40/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8599 - loss: 0.7449
# Epoch 40: val_accuracy did not improve from 0.88985
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8599 - loss: 0.7447 - val_accuracy: 0.8589 - val_loss: 0.6747 - learning_rate: 1.0000e-04
# Epoch 41/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8869 - loss: 0.6608
# Epoch 41: val_accuracy did not improve from 0.88985
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8868 - loss: 0.6609 - val_accuracy: 0.7649 - val_loss: 0.9886 - learning_rate: 1.0000e-04
# Epoch 42/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8632 - loss: 0.6478
# Epoch 42: val_accuracy did not improve from 0.88985
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8635 - loss: 0.6476 - val_accuracy: 0.8713 - val_loss: 0.6391 - learning_rate: 1.0000e-04
# Epoch 43/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8865 - loss: 0.6037
# Epoch 43: val_accuracy improved from 0.88985 to 0.92450, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8865 - loss: 0.6037 - val_accuracy: 0.9245 - val_loss: 0.5151 - learning_rate: 1.0000e-04
# Epoch 44/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8726 - loss: 0.5934
# Epoch 44: val_accuracy did not improve from 0.92450
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8727 - loss: 0.5934 - val_accuracy: 0.8391 - val_loss: 0.6581 - learning_rate: 1.0000e-04
# Epoch 45/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8975 - loss: 0.5592
# Epoch 45: val_accuracy did not improve from 0.92450
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8977 - loss: 0.5583 - val_accuracy: 0.7339 - val_loss: 1.3134 - learning_rate: 1.0000e-04
# Epoch 46/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9063 - loss: 0.5217
# Epoch 46: val_accuracy did not improve from 0.92450
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9064 - loss: 0.5216 - val_accuracy: 0.9109 - val_loss: 0.4898 - learning_rate: 1.0000e-04
# Epoch 47/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8914 - loss: 0.5246
# Epoch 47: val_accuracy improved from 0.92450 to 0.92822, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8916 - loss: 0.5244 - val_accuracy: 0.9282 - val_loss: 0.4834 - learning_rate: 1.0000e-04
# Epoch 48/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9049 - loss: 0.4982
# Epoch 48: val_accuracy did not improve from 0.92822
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9050 - loss: 0.4981 - val_accuracy: 0.9146 - val_loss: 0.4555 - learning_rate: 1.0000e-04
# Epoch 49/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9111 - loss: 0.4765
# Epoch 49: val_accuracy did not improve from 0.92822
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9111 - loss: 0.4766 - val_accuracy: 0.8193 - val_loss: 0.7067 - learning_rate: 1.0000e-04
# Epoch 50/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9035 - loss: 0.4762
# Epoch 50: val_accuracy did not improve from 0.92822
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9035 - loss: 0.4761 - val_accuracy: 0.8688 - val_loss: 0.5778 - learning_rate: 1.0000e-04
# Epoch 51/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9152 - loss: 0.4444
# Epoch 51: val_accuracy did not improve from 0.92822
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9152 - loss: 0.4445 - val_accuracy: 0.8106 - val_loss: 0.7890 - learning_rate: 1.0000e-04
# Epoch 52/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9125 - loss: 0.4156
# Epoch 52: val_accuracy did not improve from 0.92822
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9125 - loss: 0.4156 - val_accuracy: 0.9208 - val_loss: 0.3873 - learning_rate: 1.0000e-04
# Epoch 53/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9303 - loss: 0.3755
# Epoch 53: val_accuracy did not improve from 0.92822
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9301 - loss: 0.3757 - val_accuracy: 0.8837 - val_loss: 0.4778 - learning_rate: 1.0000e-04
# Epoch 54/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9282 - loss: 0.3736
# Epoch 54: val_accuracy did not improve from 0.92822
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9283 - loss: 0.3733 - val_accuracy: 0.8416 - val_loss: 0.6814 - learning_rate: 1.0000e-04
# Epoch 55/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9313 - loss: 0.3599
# Epoch 55: val_accuracy did not improve from 0.92822
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9312 - loss: 0.3599 - val_accuracy: 0.8985 - val_loss: 0.4128 - learning_rate: 1.0000e-04
# Epoch 56/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9241 - loss: 0.3734
# Epoch 56: val_accuracy did not improve from 0.92822
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9241 - loss: 0.3735 - val_accuracy: 0.8354 - val_loss: 0.6771 - learning_rate: 1.0000e-04
# Epoch 57/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9273 - loss: 0.3466
# Epoch 57: val_accuracy did not improve from 0.92822
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9273 - loss: 0.3466 - val_accuracy: 0.8936 - val_loss: 0.4284 - learning_rate: 1.0000e-04
# Epoch 58/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9139 - loss: 0.3601
# Epoch 58: val_accuracy improved from 0.92822 to 0.94802, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9140 - loss: 0.3600 - val_accuracy: 0.9480 - val_loss: 0.2921 - learning_rate: 5.0000e-05
# Epoch 59/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9279 - loss: 0.3446
# Epoch 59: val_accuracy improved from 0.94802 to 0.95297, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9281 - loss: 0.3437 - val_accuracy: 0.9530 - val_loss: 0.2750 - learning_rate: 5.0000e-05
# Epoch 60/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9364 - loss: 0.3120
# Epoch 60: val_accuracy did not improve from 0.95297
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9365 - loss: 0.3119 - val_accuracy: 0.9332 - val_loss: 0.3400 - learning_rate: 5.0000e-05
# Epoch 61/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9442 - loss: 0.2945
# Epoch 61: val_accuracy did not improve from 0.95297
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9442 - loss: 0.2945 - val_accuracy: 0.8738 - val_loss: 0.4882 - learning_rate: 5.0000e-05
# Epoch 62/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9388 - loss: 0.2994
# Epoch 62: val_accuracy did not improve from 0.95297
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9388 - loss: 0.2994 - val_accuracy: 0.9443 - val_loss: 0.2941 - learning_rate: 5.0000e-05
# Epoch 63/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9456 - loss: 0.2893
# Epoch 63: val_accuracy did not improve from 0.95297
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9455 - loss: 0.2894 - val_accuracy: 0.8775 - val_loss: 0.4782 - learning_rate: 5.0000e-05
# Epoch 64/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9461 - loss: 0.2867
# Epoch 64: val_accuracy did not improve from 0.95297
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9459 - loss: 0.2867 - val_accuracy: 0.8948 - val_loss: 0.4011 - learning_rate: 5.0000e-05
# Epoch 65/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9375 - loss: 0.2954
# Epoch 65: val_accuracy did not improve from 0.95297
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9376 - loss: 0.2953 - val_accuracy: 0.9493 - val_loss: 0.2646 - learning_rate: 2.5000e-05
# Epoch 66/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9552 - loss: 0.2499
# Epoch 66: val_accuracy did not improve from 0.95297
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9551 - loss: 0.2501 - val_accuracy: 0.8800 - val_loss: 0.5009 - learning_rate: 2.5000e-05
# Epoch 67/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9447 - loss: 0.2612
# Epoch 67: val_accuracy improved from 0.95297 to 0.95421, saving model to /home/heechun/final_ws/PoseEstimate/1114_final_pose_check/best_model_final_data_change.keras
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9448 - loss: 0.2612 - val_accuracy: 0.9542 - val_loss: 0.2497 - learning_rate: 2.5000e-05
# Epoch 68/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9380 - loss: 0.2910
# Epoch 68: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9381 - loss: 0.2906 - val_accuracy: 0.9171 - val_loss: 0.3354 - learning_rate: 2.5000e-05
# Epoch 69/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9527 - loss: 0.2586
# Epoch 69: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9527 - loss: 0.2582 - val_accuracy: 0.9233 - val_loss: 0.3117 - learning_rate: 2.5000e-05
# Epoch 70/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9464 - loss: 0.2751
# Epoch 70: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9464 - loss: 0.2751 - val_accuracy: 0.9455 - val_loss: 0.2940 - learning_rate: 2.5000e-05
# Epoch 71/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9430 - loss: 0.2738
# Epoch 71: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9430 - loss: 0.2735 - val_accuracy: 0.9480 - val_loss: 0.2820 - learning_rate: 2.5000e-05
# Epoch 72/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9504 - loss: 0.2490
# Epoch 72: val_accuracy did not improve from 0.95421
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9505 - loss: 0.2490 - val_accuracy: 0.9369 - val_loss: 0.2746 - learning_rate: 2.5000e-05
# Epoch 73/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9586 - loss: 0.2404
# Epoch 73: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9586 - loss: 0.2406 - val_accuracy: 0.9282 - val_loss: 0.3188 - learning_rate: 1.2500e-05
# Epoch 74/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9602 - loss: 0.2284
# Epoch 74: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9601 - loss: 0.2285 - val_accuracy: 0.9542 - val_loss: 0.2519 - learning_rate: 1.2500e-05
# Epoch 75/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9495 - loss: 0.2508
# Epoch 75: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9497 - loss: 0.2507 - val_accuracy: 0.9530 - val_loss: 0.2543 - learning_rate: 1.2500e-05
# Epoch 76/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9587 - loss: 0.2232
# Epoch 76: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9587 - loss: 0.2237 - val_accuracy: 0.9381 - val_loss: 0.2794 - learning_rate: 1.2500e-05
# Epoch 77/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9482 - loss: 0.2459
# Epoch 77: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9482 - loss: 0.2461 - val_accuracy: 0.9542 - val_loss: 0.2461 - learning_rate: 1.2500e-05
# Epoch 78/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9599 - loss: 0.2424
# Epoch 78: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9597 - loss: 0.2424 - val_accuracy: 0.9517 - val_loss: 0.2522 - learning_rate: 1.2500e-05
# Epoch 79/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9595 - loss: 0.2240
# Epoch 79: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9592 - loss: 0.2247 - val_accuracy: 0.9517 - val_loss: 0.2505 - learning_rate: 1.2500e-05
# Epoch 80/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9563 - loss: 0.2420
# Epoch 80: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9563 - loss: 0.2420 - val_accuracy: 0.9505 - val_loss: 0.2552 - learning_rate: 1.2500e-05
# Epoch 81/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9562 - loss: 0.2266
# Epoch 81: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9562 - loss: 0.2267 - val_accuracy: 0.9468 - val_loss: 0.2536 - learning_rate: 1.2500e-05
# Epoch 82/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9461 - loss: 0.2538
# Epoch 82: val_accuracy did not improve from 0.95421
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9461 - loss: 0.2538 - val_accuracy: 0.9530 - val_loss: 0.2470 - learning_rate: 1.2500e-05
# Epoch 83/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9603 - loss: 0.2153
# Epoch 83: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9603 - loss: 0.2156 - val_accuracy: 0.9530 - val_loss: 0.2442 - learning_rate: 6.2500e-06
# Epoch 84/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9543 - loss: 0.2290
# Epoch 84: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9543 - loss: 0.2290 - val_accuracy: 0.9542 - val_loss: 0.2471 - learning_rate: 6.2500e-06
# Epoch 85/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9449 - loss: 0.2517
# Epoch 85: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9450 - loss: 0.2515 - val_accuracy: 0.9517 - val_loss: 0.2485 - learning_rate: 6.2500e-06
# Epoch 86/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9634 - loss: 0.2096
# Epoch 86: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9632 - loss: 0.2102 - val_accuracy: 0.9517 - val_loss: 0.2457 - learning_rate: 6.2500e-06
# Epoch 87/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9563 - loss: 0.2235
# Epoch 87: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9563 - loss: 0.2236 - val_accuracy: 0.9517 - val_loss: 0.2461 - learning_rate: 6.2500e-06
# Epoch 88/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9662 - loss: 0.2088
# Epoch 88: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9661 - loss: 0.2093 - val_accuracy: 0.9493 - val_loss: 0.2410 - learning_rate: 6.2500e-06
# Epoch 89/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9503 - loss: 0.2399
# Epoch 89: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9505 - loss: 0.2395 - val_accuracy: 0.9530 - val_loss: 0.2434 - learning_rate: 6.2500e-06
# Epoch 90/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9565 - loss: 0.2165
# Epoch 90: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9566 - loss: 0.2166 - val_accuracy: 0.9493 - val_loss: 0.2451 - learning_rate: 6.2500e-06
# Epoch 91/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9636 - loss: 0.2152
# Epoch 91: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9633 - loss: 0.2156 - val_accuracy: 0.9517 - val_loss: 0.2378 - learning_rate: 6.2500e-06
# Epoch 92/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9607 - loss: 0.2152
# Epoch 92: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9606 - loss: 0.2152 - val_accuracy: 0.9517 - val_loss: 0.2360 - learning_rate: 6.2500e-06
# Epoch 93/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9521 - loss: 0.2257
# Epoch 93: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9521 - loss: 0.2258 - val_accuracy: 0.9517 - val_loss: 0.2376 - learning_rate: 6.2500e-06
# Epoch 94/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9627 - loss: 0.2116
# Epoch 94: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9626 - loss: 0.2117 - val_accuracy: 0.9530 - val_loss: 0.2432 - learning_rate: 6.2500e-06
# Epoch 95/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9630 - loss: 0.2119
# Epoch 95: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9629 - loss: 0.2123 - val_accuracy: 0.9517 - val_loss: 0.2399 - learning_rate: 6.2500e-06
# Epoch 96/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9588 - loss: 0.2176
# Epoch 96: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9588 - loss: 0.2177 - val_accuracy: 0.9530 - val_loss: 0.2421 - learning_rate: 6.2500e-06
# Epoch 97/100
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9495 - loss: 0.2519
# Epoch 97: val_accuracy did not improve from 0.95421
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9495 - loss: 0.2517 - val_accuracy: 0.9517 - val_loss: 0.2403 - learning_rate: 6.2500e-06
# Epoch 98/100
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9610 - loss: 0.2102
# Epoch 98: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9610 - loss: 0.2103 - val_accuracy: 0.9505 - val_loss: 0.2405 - learning_rate: 3.1250e-06
# Epoch 99/100
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9575 - loss: 0.2148
# Epoch 99: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9576 - loss: 0.2147 - val_accuracy: 0.9505 - val_loss: 0.2390 - learning_rate: 3.1250e-06
# Epoch 100/100
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9569 - loss: 0.2339
# Epoch 100: val_accuracy did not improve from 0.95421
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9569 - loss: 0.2337 - val_accuracy: 0.9517 - val_loss: 0.2403 - learning_rate: 3.1250e-06
# Restoring model weights from the end of the best epoch: 92.
